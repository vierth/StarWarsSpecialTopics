# %%
import re 

location_list = ["Naboo", "Tatooine", "Coruscant", "Kamino", "Geonosis", "Utapau", "Kashyyyk", "Mustafar", "Polis Massa", "Alderaan", "Mos Eisley", "Yavin IV", "Hoth", "Dagobah", "Bespin", "Endor", "Sullust"]

text = open('starwars1.txt', 'r').read()

n = 136

dialogueregex = '(^[\tA-Z 0-9&-]+):?\n?(.+)(?!\n\n)'


#extract dialogue per text_chunk (can differentiate with every script)
#same format in sw3, rest needs code that searches for double enter
#double linerbreaks=https://stackoverflow.com/questions/18629494/regex-double-new-line
results = re.finditer(dialogueregex, text, re.MULTILINE)




def divide_text(text, n):
    part_size = round(len(text)/n)
    mentioned_locations = []
    for i in range(0,n):
        if i < n -1:
            text_chunk = text[i*part_size:(i+1)*part_size]
        else:
            text_chunk = text[i*part_size:]
        mentioned_locations.append(get_locations(text_chunk)) 
    return mentioned_locations


def get_locations(text_chunk):
    m_locations =[]
    results = re.finditer(dialogueregex, text_chunk, re.MULTILINE)
    
    for result in results:
        for location in location_list:
            if location in result.group(2):
                m_locations.append(location)
    return m_locations
            
divide_text(text, n)
# Out:
# [['Naboo', 'Naboo'],
#  [],
#  ['Naboo'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Naboo'],
#  [],
#  [],
#  ['Naboo'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Naboo', 'Naboo', 'Naboo', 'Naboo', 'Naboo'],
#  [],
#  [],
#  [],
#  [],
#  ['Naboo'],
#  [],
#  [],
#  ['Naboo', 'Coruscant'],
#  [],
#  ['Naboo', 'Coruscant', 'Coruscant', 'Coruscant'],
#  ['Naboo'],
#  [],
#  ['Naboo', 'Coruscant', 'Tatooine'],
#  ['Naboo', 'Naboo'],
#  ['Tatooine'],
#  ['Naboo', 'Tatooine'],
#  ['Tatooine', 'Naboo'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Naboo'],
#  [],
#  [],
#  [],
#  ['Naboo'],
#  [],
#  [],
#  [],
#  ['Tatooine', 'Naboo', 'Naboo'],
#  [],
#  ['Coruscant'],
#  [],
#  [],
#  ['Naboo'],
#  ['Naboo'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Tatooine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Naboo'],
#  [],
#  [],
#  [],
#  ['Naboo'],
#  [],
#  ['Naboo', 'Tatooine'],
#  ['Tatooine'],
#  [],
# ...

# %%
import re 

location_list = ["Utapau", "Naboo", "Tatooine", "Coruscant", "Kamino", "Geonosis", "Utapau", "Kashyyyk", "Mustafar", "Polis Massa", "Alderaan", "Mos Eisley", "Yavin IV", "Hoth", "Dagobah", "Bespin", "Endor", "Sullust"]

text = open('starwars2.txt', 'r').read()

n = 142

dialogueregex = '(^[\tA-Z 0-9&-]+):?\n?(.+)(?!\n\n)'



results = re.finditer(dialogueregex, text, re.MULTILINE)




def divide_text(text, n):
    part_size = round(len(text)/n)
    mentioned_locations = []
    for i in range(0,n):
        if i < n -1:
            text_chunk = text[i*part_size:(i+1)*part_size]
        else:
            text_chunk = text[i*part_size:]
        mentioned_locations.append(get_locations(text_chunk)) 
    return mentioned_locations


def get_locations(text_chunk):
    m_locations =[]
    results = re.finditer(dialogueregex, text_chunk, re.MULTILINE)
    
    for result in results:
        for location in location_list:
            if location in result.group(2):
                m_locations.append(location)
    return m_locations
            
divide_text(text, n)
# Out:
# [['Coruscant', 'Naboo', 'Coruscant', 'Naboo', 'Naboo'],
#  [],
#  [],
#  ['Naboo'],
#  [],
#  ['Naboo'],
#  [],
#  [],
#  ['Naboo'],
#  [],
#  ['Coruscant'],
#  [],
#  ['Tatooine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Coruscant'],
#  ['Naboo'],
#  ['Coruscant'],
#  [],
#  [],
#  ['Naboo', 'Naboo'],
#  ['Naboo', 'Tatooine'],
#  [],
#  ['Kamino', 'Kamino'],
#  ['Kamino'],
#  [],
#  [],
#  ['Coruscant'],
#  [],
#  [],
#  ['Naboo'],
#  [],
#  [],
#  ['Kamino', 'Kamino'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Naboo'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Kamino'],
#  ['Kamino', 'Kamino'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Naboo'],
#  [],
#  ['Naboo'],
#  [],
#  ['Coruscant'],
#  ['Naboo', 'Tatooine', 'Naboo'],
#  [],
#  [],
#  [],
#  ['Kamino'],
#  [],
#  [],
#  ['Naboo'],
#  [],
#  [],
# ...

# %%
import re 

location_list = ["Naboo", "Tatooine", "Coruscant", "Kamino", "Geonosis", "Utapau", "Kashyyyk", "Mustafar", "Polis Massa", "Alderaan", "Mos Eisley", "Yavin IV", "Hoth", "Dagobah", "Bespin", "Endor", "Sullust"]

text = open('starwars3.txt', 'r').read()

n = 140

dialogueregex = '(^[\tA-Z 0-9&-]+):?\n?(.+)(?!\n\n)'

results = re.finditer(dialogueregex, text, re.MULTILINE)

def divide_text(text, n):
    part_size = round(len(text)/n)
    mentioned_locations = []
    for i in range(0,n):
        if i < n -1:
            text_chunk = text[i*part_size:(i+1)*part_size]
        else:
            text_chunk = text[i*part_size:]
        mentioned_locations.append(get_locations(text_chunk)) 
    return mentioned_locations




def get_locations(text_chunk):
    m_locations =[]
    results = re.finditer(dialogueregex, text_chunk, re.MULTILINE)
    for result in results:
        
        for location in location_list:
            if location in result.group(2):
                m_locations.append(location)
    return m_locations



divide_text(text, n)
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Coruscant'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Coruscant'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Mustafar', 'Naboo'],
#  ['Coruscant'],
#  [],
#  [],
#  [],
#  ['Coruscant'],
#  [],
#  [],
#  [],
#  [],
#  ['Kashyyyk'],
#  [],
#  [],
#  ['Kashyyyk'],
#  [],
#  ['Naboo'],
#  ['Utapau'],
#  [],
#  [],
#  ['Utapau', 'Utapau'],
#  [],
#  ['Coruscant'],
#  [],
#  [],
#  ['Utapau'],
#  ['Utapau'],
#  ['Utapau', 'Naboo'],
#  [],
#  ['Utapau'],
#  [],
#  [],
#  [],
#  ['Mustafar'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Mustafar'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Alderaan'],
#  ['Utapau'],
#  [],
#  [],
#  ['Mustafar'],
#  [],
#  ['Coruscant'],
# ...

# %%
import re 

location_list = ["Utapau", "Naboo", "Tatooine", "Coruscant", "Kamino", "Geonosis", "Utapau", "Kashyyyk", "Mustafar", "Polis Massa", "Alderaan", "Mos Eisley", "Yavin IV", "Hoth", "Dagobah", "Bespin", "Endor", "Sullust"]

text = open('starwars4.txt', 'r').read()

n = 121

dialogueregex = '(^[\tA-Z 0-9&-]+):?\n?(.+)(?!\n\n)'



results = re.finditer(dialogueregex, text, re.MULTILINE)




def divide_text(text, n):
    part_size = round(len(text)/n)
    mentioned_locations = []
    for i in range(0,n):
        if i < n -1:
            text_chunk = text[i*part_size:(i+1)*part_size]
        else:
            text_chunk = text[i*part_size:]
        mentioned_locations.append(get_locations(text_chunk)) 
    return mentioned_locations


def get_locations(text_chunk):
    m_locations =[]
    results = re.finditer(dialogueregex, text_chunk, re.MULTILINE)
    for result in results:
        for location in location_list:
            if location in result.group(2):
                m_locations.append(location)
    return m_locations
            
divide_text(text, n)
# Out:
# [['Tatooine'],
#  [],
#  [],
#  ['Alderaan'],
#  [],
#  [],
#  [],
#  ['Tatooine'],
#  ['Mos Eisley'],
#  [],
#  [],
#  ['Tatooine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Tatooine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Alderaan'],
#  ['Alderaan', 'Alderaan', 'Mos Eisley'],
#  [],
#  [],
#  ['Alderaan', 'Mos Eisley', 'Mos Eisley'],
#  [],
#  [],
#  [],
#  ['Alderaan'],
#  [],
#  ['Alderaan'],
#  [],
#  [],
#  ['Tatooine', 'Tatooine'],
#  [],
#  ['Alderaan', 'Alderaan', 'Alderaan'],
#  ['Alderaan', 'Alderaan', 'Alderaan'],
#  [],
#  [],
#  ['Alderaan'],
#  [],
#  ['Alderaan'],
#  [],
#  [],
#  ['Alderaan'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Alderaan'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
import re 

location_list = ["Utapau", "Naboo", "Tatooine", "Coruscant", "Kamino", "Geonosis", "Utapau", "Kashyyyk", "Mustafar", "Polis Massa", "Alderaan", "Mos Eisley", "Yavin IV", "Hoth", "Dagobah", "Bespin", "Endor", "Sullust"]

text = open('starwars5.txt', 'r').read()

n = 125

dialogueregex = '(^[\tA-Z 0-9&-]+):?\n?(.+)(?!\n\n)'



results = re.finditer(dialogueregex, text, re.MULTILINE)




def divide_text(text, n):
    part_size = round(len(text)/n)
    mentioned_locations = []
    for i in range(0,n):
        if i < n -1:
            text_chunk = text[i*part_size:(i+1)*part_size]
        else:
            text_chunk = text[i*part_size:]
        mentioned_locations.append(get_locations(text_chunk)) 
    return mentioned_locations


def get_locations(text_chunk):
    m_locations =[]
    results = re.finditer(dialogueregex, text_chunk, re.MULTILINE)
    for result in results:
        for location in location_list:
            if location in result.group(2):
                m_locations.append(location)
    return m_locations
            
divide_text(text, n)
# Out:
# [['Hoth'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Dagobah', 'Dagobah'],
#  ['Dagobah', 'Dagobah'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Hoth', 'Hoth'],
#  ['Hoth'],
#  [],
#  ['Hoth'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Hoth'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Dagobah', 'Hoth'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Dagobah', 'Dagobah'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Bespin'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Dagobah'],
#  [],
#  [],
#  [],
#  ['Bespin'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
# ...

# %%
import re 

location_list = ["Utapau", "Naboo", "Tatooine", "Coruscant", "Kamino", "Geonosis", "Utapau", "Kashyyyk", "Mustafar", "Polis Massa", "Alderaan", "Mos Eisley", "Yavin IV", "Hoth", "Dagobah", "Bespin", "Endor", "Sullust"]

text = open('starwars6.txt', 'r').read()

n = 131

dialogueregex = '(^[\tA-Z 0-9&-]+):?\n?(.+)(?!\n\n)'



results = re.finditer(dialogueregex, text, re.MULTILINE)




def divide_text(text, n):
    part_size = round(len(text)/n)
    mentioned_locations = []
    for i in range(0,n):
        if i < n -1:
            text_chunk = text[i*part_size:(i+1)*part_size]
        else:
            text_chunk = text[i*part_size:]
        mentioned_locations.append(get_locations(text_chunk)) 
    return mentioned_locations


def get_locations(text_chunk):
    m_locations =[]
    results = re.finditer(dialogueregex, text_chunk, re.MULTILINE)
    for result in results:
        for location in location_list:
            if location in result.group(2):
                m_locations.append(location)
    return m_locations
            
divide_text(text, n)
# Out:
# [['Tatooine'],
#  ['Endor'],
#  ['Tatooine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Dagobah'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Endor'],
#  ['Endor'],
#  [],
#  [],
#  ['Endor'],
#  ['Endor', 'Sullust'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Endor'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Endor'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Bespin'],
#  [],
#  []]
